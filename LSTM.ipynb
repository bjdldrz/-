# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader,Dataset

# %%
seq_len = 96
predict_len = 96
hidden_size = 50
output_size = 1
num_layers = 5
batch_size = 256
lr = 0.001
num_epochs = 100
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
#首先制作数据集
def get_data(csv,item,seq_len,predict_len):
    full_data = pd.read_csv(csv)
    data = full_data[item]
    
    data = np.array(data)
    
    x = []
    y = []
    
    for i in range(data.shape[0]-seq_len-predict_len):
        x_one = data[i:i+seq_len]
        y_one = data[i+seq_len:i+seq_len+predict_len]
        
        x_one = np.array(x_one)
        y_one = np.array(y_one)
        
        
        x.append(x_one)
        y.append(y_one)
        
    x = np.array(x)
    max_value = np.max(x)
    min_value = np.min(x)
    x = (x-min_value) / (max_value-min_value)
    y = np.array(y)
    
    
    train = int(x.shape[0]*0.8)
    valid = int(x.shape[0]*0.1)
    x_train,x_valid,x_test = x[:train],x[train:train+valid],x[train+valid:]
    y_train,y_valid,x_test = y[:train],y[train:train+valid],y[train+valid:]
    
    return x_train,x_valid,x_test,y_train,y_valid,x_test

# %%
x_train,x_valid,x_test,y_train,y_valid,y_test = get_data('./data/stations_data/df_station_1001.csv','PM25_Concentration',seq_len,predict_len)

# %%
class Mydataset(Dataset):
    def __init__(self,x,y,transform=None):
        self.x = x
        self.y = y
        self.transform = transform
    
    def __len__(self):
        return len(self.x)
    
    def __getitem__(self,idx):
        x = self.x[idx]
        if self.transform:
            x = self.transform(x)
        return x,self.y[idx]

# %%
train_dataset = Mydataset(x_train,y_train)
valid_dataset = Mydataset(x_valid,y_valid)
test_dataset = Mydataset(x_test,y_test)
train_loader = DataLoader(dataset=train_dataset,batch_size=batch_size,shuffle=True)
valid_loader = DataLoader(dataset=valid_dataset,batch_size=batch_size,shuffle=True)
test_loader = DataLoader(dataset=test_dataset,batch_size=batch_size,shuffle=True)

# %%
for i,(x,y) in enumerate(test_loader):
    print(x.shape)
    print(y.shape)
# Out:
# torch.Size([256, 96])
# torch.Size([256, 96])
# torch.Size([256, 96])
# torch.Size([256, 96])
# torch.Size([256, 96])
# torch.Size([256, 96])
# torch.Size([90, 96])
# torch.Size([90, 96])

# %%
class MultiStepLSTMPredictor(nn.Module):
    def __init__(self, input_size, hidden_size, output_size, num_layers, seq_len):
        super(MultiStepLSTMPredictor, self).__init__()
        self.hidden_size = hidden_size
        self.num_layers = num_layers
        self.seq_len = seq_len  # 预测序列的长度
        self.output_size = output_size
        self.lstm = nn.LSTM(input_size, hidden_size, num_layers, batch_first=True)
        self.fc = nn.Linear(hidden_size, output_size * seq_len)  # 输出所有未来时间步的预测

    def forward(self, x):
        h0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(x.device)
        c0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(x.device)
        
        out, _ = self.lstm(x, (h0, c0))
        
        # 将隐藏状态的最后一个时间步输出通过全连接层
        out = self.fc(out[:, -1, :])
        # 重塑输出以匹配多步预测的形状
        out = out.view(-1, self.seq_len, self.output_size)
        
        return out

# %%
model = MultiStepLSTMPredictor(seq_len, hidden_size, output_size, num_layers, predict_len).to(device)

# %%
criterion = nn.MSELoss()
optimizer = optim.Adam(model.parameters(),lr = lr)

# %%
# 训练模型
losses = []
val_losses = []
patience = 20  # 允许没有性能提升的epoch数量
# 初始化最佳损失和epoch计数器
best_loss = float('inf')
for epoch in range(num_epochs):
    for i,(x,y) in enumerate(train_loader):
        model.train()
        x = x.float().unsqueeze(dim=1).to(device)
        y = y.float().to(device)
        model.zero_grad()
        output = model(x).to(device).squeeze()
        loss = criterion(output,y)
        loss.backward()
        
        optimizer.step()
        
        if i % 20 == 0:
            print('epoch:{}/{},batch:{},loss:{:.4f}'.format(epoch,num_epochs,i,loss.item()))
            losses.append(loss.item())
            
    model.eval()   
    validation_losses = []
    with torch.no_grad():
        for i,(x,y) in enumerate(valid_loader):
            model.train()
            x = x.float().unsqueeze(dim=1).to(device)
            y = y.float().to(device)
            output = model(x).to(device).squeeze()
            loss = criterion(output,y)
            validation_losses.append(loss.item())
        
        # 验证过程...
        validation_losses = np.array(validation_losses)
        validation_loss = np.mean(validation_losses)  # 计算验证集损失
        val_losses.append(validation_loss)
        
    
        # 检查是否是最佳模型
        if validation_loss < best_loss:
            best_loss = validation_loss
            print('best_loss:{:.4f}'.format(best_loss))
            epoch_no_improve = 0
            # 保存最佳模型的状态
            torch.save(model.state_dict(), 'best_model_lstm.pth')
        else:
            epoch_no_improve += 1
            print('validation_loss:{:.4f}'.format(validation_loss))
            print('epoch_no_improve:{}'.format(epoch_no_improve))
            if epoch_no_improve >= patience:
                print(f"Early stopping initiated after {epoch_no_improve} epochs without improvement.")
                break
# Out:
# epoch:0/100,batch:0,loss:12179.2764
# epoch:0/100,batch:20,loss:11286.2139
# best_loss:15758.4246
# epoch:1/100,batch:0,loss:9911.4863
# epoch:1/100,batch:20,loss:8916.3125
# best_loss:14125.3713
# epoch:2/100,batch:0,loss:10606.3984
# epoch:2/100,batch:20,loss:9002.7852
# best_loss:12288.0676
# epoch:3/100,batch:0,loss:8558.3008
# epoch:3/100,batch:20,loss:8561.9912
# best_loss:11254.0269
# epoch:4/100,batch:0,loss:7428.2783
# epoch:4/100,batch:20,loss:8200.1758
# best_loss:10668.0793
# epoch:5/100,batch:0,loss:7837.4922
# epoch:5/100,batch:20,loss:7207.0015
# best_loss:9599.4863
# epoch:6/100,batch:0,loss:7700.4585
# epoch:6/100,batch:20,loss:5759.5293
# best_loss:9537.2212
# epoch:7/100,batch:0,loss:5983.9551
# epoch:7/100,batch:20,loss:5636.3965
# best_loss:8796.5204
# epoch:8/100,batch:0,loss:6317.3867
# epoch:8/100,batch:20,loss:6009.1992
# validation_loss:8845.6418
# epoch_no_improve:1
# epoch:9/100,batch:0,loss:7203.1631
# epoch:9/100,batch:20,loss:6548.0732
# best_loss:8474.0796
# epoch:10/100,batch:0,loss:5952.1226
# epoch:10/100,batch:20,loss:7456.0952
# best_loss:8400.0166
# epoch:11/100,batch:0,loss:6199.0835
# epoch:11/100,batch:20,loss:5597.8257
# best_loss:8239.6243
# epoch:12/100,batch:0,loss:6538.6421
# epoch:12/100,batch:20,loss:5578.7124
# best_loss:8235.0435
# epoch:13/100,batch:0,loss:6541.7266
# epoch:13/100,batch:20,loss:5213.0264
# best_loss:7996.1595
# epoch:14/100,batch:0,loss:6221.0093
# epoch:14/100,batch:20,loss:5850.8003
# validation_loss:8293.5186
# epoch_no_improve:1
# epoch:15/100,batch:0,loss:6053.3574
# epoch:15/100,batch:20,loss:5641.1016
# validation_loss:8158.1348
# epoch_no_improve:2
# epoch:16/100,batch:0,loss:6876.1357
# epoch:16/100,batch:20,loss:5889.4590
# validation_loss:8099.2870
# epoch_no_improve:3
# epoch:17/100,batch:0,loss:5447.6172
# epoch:17/100,batch:20,loss:5460.0732
# validation_loss:8054.8113
# epoch_no_improve:4
# epoch:18/100,batch:0,loss:5577.9385
# epoch:18/100,batch:20,loss:6505.8906
# validation_loss:8079.1854
# epoch_no_improve:5
# epoch:19/100,batch:0,loss:6400.2275
# epoch:19/100,batch:20,loss:6506.2959
# validation_loss:8034.1981
# epoch_no_improve:6
# epoch:20/100,batch:0,loss:6180.6709
# epoch:20/100,batch:20,loss:6083.3745
# best_loss:7933.8630
# epoch:21/100,batch:0,loss:5655.8394
# epoch:21/100,batch:20,loss:6295.7334
# validation_loss:8037.9814
# epoch_no_improve:1
# epoch:22/100,batch:0,loss:6690.6851
# epoch:22/100,batch:20,loss:6345.2710
# validation_loss:8261.8754
# epoch_no_improve:2
# epoch:23/100,batch:0,loss:5808.5640
# epoch:23/100,batch:20,loss:5860.3779
# validation_loss:8063.0729
# epoch_no_improve:3
# epoch:24/100,batch:0,loss:5153.8682
# epoch:24/100,batch:20,loss:6189.9233
# validation_loss:8083.8571
# epoch_no_improve:4
# epoch:25/100,batch:0,loss:6937.9844
# epoch:25/100,batch:20,loss:5835.7734
# validation_loss:8086.1205
# epoch_no_improve:5
# epoch:26/100,batch:0,loss:6446.6826
# epoch:26/100,batch:20,loss:6318.0596
# validation_loss:8056.2533
# epoch_no_improve:6
# epoch:27/100,batch:0,loss:6445.3701
# epoch:27/100,batch:20,loss:5287.9092
# validation_loss:8058.7073
# epoch_no_improve:7
# epoch:28/100,batch:0,loss:5443.0225
# epoch:28/100,batch:20,loss:6439.9238
# validation_loss:8079.0680
# epoch_no_improve:8
# epoch:29/100,batch:0,loss:5959.1484
# epoch:29/100,batch:20,loss:6267.3335
# validation_loss:8121.9456
# epoch_no_improve:9
# epoch:30/100,batch:0,loss:5973.2041
# epoch:30/100,batch:20,loss:6551.8159
# validation_loss:8112.3364
# epoch_no_improve:10
# epoch:31/100,batch:0,loss:7370.3770
# epoch:31/100,batch:20,loss:5628.0342
# validation_loss:8163.7375
# epoch_no_improve:11
# epoch:32/100,batch:0,loss:5717.3511
# epoch:32/100,batch:20,loss:5963.2632
# validation_loss:8137.0057
# epoch_no_improve:12
# epoch:33/100,batch:0,loss:6244.1050
# epoch:33/100,batch:20,loss:6223.0928
# validation_loss:8220.9598
# epoch_no_improve:13
# epoch:34/100,batch:0,loss:5733.4951
# epoch:34/100,batch:20,loss:5620.6729
# validation_loss:8017.0122
# epoch_no_improve:14
# epoch:35/100,batch:0,loss:6301.6616
# epoch:35/100,batch:20,loss:6097.5898
# validation_loss:7983.8243
# epoch_no_improve:15
# epoch:36/100,batch:0,loss:6338.8608
# epoch:36/100,batch:20,loss:6049.1006
# validation_loss:7962.8545
# epoch_no_improve:16
# epoch:37/100,batch:0,loss:5716.0801
# epoch:37/100,batch:20,loss:6010.4448
# validation_loss:7981.2045
# epoch_no_improve:17
# epoch:38/100,batch:0,loss:6086.8701
# epoch:38/100,batch:20,loss:6053.0342
# validation_loss:7988.1467
# epoch_no_improve:18
# epoch:39/100,batch:0,loss:5280.1929
# epoch:39/100,batch:20,loss:5806.8672
# validation_loss:8203.9849
# epoch_no_improve:19
# epoch:40/100,batch:0,loss:5568.3398
# epoch:40/100,batch:20,loss:5694.9272
# validation_loss:8183.6960
# epoch_no_improve:20
# Early stopping initiated after 20 epochs without improvement.

# %%
#接下来为测试过程，
test_model = MultiStepLSTMPredictor(seq_len, hidden_size, output_size, num_layers, predict_len).to(device)
test_model.load_state_dict(torch.load('best_model_lstm.pth'))
# Out:
# <All keys matched successfully>

# %%
from matplotlib import pyplot as plt
losses = np.array(losses)
val_losses = np.array(val_losses)
fig, ax = plt.subplots()
ax.plot(losses)
ax.plot(val_losses)
plt.show()

# %%
def test(model,device,test_loader):
    histories = []
    predicts = []
    ground_truth=[]
    model.eval()
    mse = nn.MSELoss()
    
    
    with torch.no_grad():
        for i,(x,y) in enumerate(test_loader):
            model.eval()
            x = x.float().unsqueeze(dim=1).to(device)
            y = y.float().to(device)
            output = model(x).to(device).squeeze()
            loss = criterion(output,y)
            print('Test Loss:{:.4f}'.format(loss.item()))
            
            histories.append(x)
            predicts.append(output)
            ground_truth.append(y)
            
        return histories,predicts,ground_truth

# %%
histories,predicts,ground_truth = test(test_model,device,test_loader)
# Out:
# Test Loss:2662.2109
# Test Loss:2626.9517
# Test Loss:2497.5667
# Test Loss:2669.6338

# %%
predicts[0].shape
# Out:
# torch.Size([256, 96])

# %%
ground_truth[0].shape
# Out:
# torch.Size([256, 96])

# %%
x1 = np.arange(histories[0].shape[2],histories[0].shape[2]+predicts[0].shape[1])
x2 = np.arange(histories[0].shape[2])
print(x1)
for i in range(10):
    y1 = predicts[0][i*10].cpu()
    y2 = ground_truth[0][i*10].cpu()
    y3 = histories[0][i,0,:].cpu()

    fig, ax = plt.subplots()
    ax.plot(x1, y1, label='predicts', color='blue')
    ax.plot(x1, y2, label='ground_truth', color='red')
    #ax.plot(x2,y3,label = 'histories',color='green')

    plt.show()
# Out:
# [ 96  97  98  99 100 101 102 103 104 105 106 107 108 109 110 111 112 113
#  114 115 116 117 118 119 120 121 122 123 124 125 126 127 128 129 130 131
#  132 133 134 135 136 137 138 139 140 141 142 143 144 145 146 147 148 149
#  150 151 152 153 154 155 156 157 158 159 160 161 162 163 164 165 166 167
#  168 169 170 171 172 173 174 175 176 177 178 179 180 181 182 183 184 185
#  186 187 188 189 190 191]
